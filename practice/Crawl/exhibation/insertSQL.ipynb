# %%
import pymysql

# 連線語法

host = "localhost"
port = 8889
user = "root"
password = "root"
database = "midReport"

conn = pymysql.connect(host=host,port=port, user=user, password=password, db=database)

cursor = conn.cursor()

# data = cursor.execute("SELECT VERSION();")
cursor.execute("SELECT * FROM exhibition;")
cursor.fetchall()
# cursor.execute("SELECT VERSION();")
# fetchmany(4)

# {'name': '玻璃的異想世界｜GOODGLAS快閃店', 
#  'date': '2019/09/05-11/04', 
#  'catagory': '期間限定店', 
#  'id': '19090614251186265', 
#  'link': 'https://www.huashan1914.com/w/huashan1914/exhibition_19090614251186265', 
#  'place': '華山'}
realData = []
realData = [(ele['name'], ele['date'], ele['place'], ele['id'], ele['link'],ele['catagory'],"huashan") for ele in HSRawData]

# realData
cursor.executemany("INSERT INTO exhibition (name,date,place,id,link,catagory,enPlace) VALUES(%s,%s,%s,%s,%s,%s,%s)",realData)

conn.commit()

# realData
print('done')
# Out:
# done

# %%
realData[0]
# Out:
# ('ETtoday好朋友放閃音樂節',
#  '2019/11/09',
#  '華山',
#  '19100309163248463',
#  'https://www.huashan1914.com/w/huashan1914/exhibition_19100309163248463',
#  '展演活動品牌活動',
#  'huashan')

# %%
for item in realData:
    cursor.execute("INSERT INTO exhibition (name,date,place,id,link,catagory,enPlace) VALUES(%s,%s,%s,%s,%s,%s,%s)",item)
    
    print(item)
    print(done)

    conn.commit()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-f85cfccefc52> in <module>
#       1 for item in realData:
# ----> 2     cursor.execute("INSERT INTO exhibition (name,date,place,id,link,catagory,enPlace) VALUES(%s,%s,%s,%s,%s,%s,%s)",item)
#       3
#       4     print(item)
#       5     print(done)
#
# ~/miniconda3/lib/python3.7/site-packages/pymysql/cursors.py in execute(self, query, args)
#     168         query = self.mogrify(query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#     172         return result
#
# ~/miniconda3/lib/python3.7/site-packages/pymysql/cursors.py in _query(self, q)
#     326         self._last_executed = q
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#     330         return self.rowcount
#
# ...

# %%
SSrawData=[[{'Title': '2019原創基地節',
   'PublishDate': '2019/11/29~2019/12/08',
   'Place': '松菸',
   'shortInfo': '遊走於松菸的地景藝術—相會在原創基地節\r\n\r\n連續七年在十二月舉辦的松山文創園區「原創基地節」，是歲末最受歡迎的大型活動，邀集數十位藝術家和文創品牌攜手打造創意聚集，每每在寒風至，這年即將結束時，讓眾人深切期待到來；「原創基地節」充滿熱情充滿創意，在冷冷冬日裡，讓松山文創園區暖暖綻放光彩。\r\n\r\n一期一會，如此簡單的相會，我們與藝術與文創與古蹟，這般親近。\r\n\r\n',
   'ID': 'e4bf4a34-3a20-478d-b846-c328def63fef',
   'link': 'https://www.songshanculturalpark.org/Exhibition.aspx?ID=e4bf4a34-3a20-478d-b846-c328def63fef'},
  {'Title': '臺東地方文化館生活日特展《臺東日常的動靜之間》',
   'PublishDate': '2019/11/09~2019/11/10',
   'Place': '松菸',
   'shortInfo': '臺東地方文化館生活日特展-臺東日常的動靜之間是由臺東縣政府文化處主辦，帶領9間地方文化館舍，首次於縣外聯合策展，臺東的多元族群形塑出繽紛多元文化場域，將臺東日常縮影濃縮於這次的展覽中，期盼民眾走進特展，探看臺東日常的動靜之美，細品臺東在地文化的縮影，感受臺東生活的況味，你會愛上這個動靜皆迷人的地方，臺東。',
   'ID': '26fcfaca-b936-4dd0-894c-5fcff5e27900',
   'link': 'https://www.songshanculturalpark.org/Exhibition.aspx?ID

   'link': 'https://www.songshanculturalpark.org/Exhibition.aspx?ID=68bdfa46-9f6f-439b-9d9e-6599f07c8b5b'},
  {'Title': '生活的形狀—新竹縣工藝展',
   'PublishDate': '2019/10/26~2019/11/03',
   'Place': '松菸',
   'shortInfo': '新竹縣生活的形狀，是什麼樣子？\r\n\r\n日本民藝運動之父柳宗悅曾說：「美是用的體現，用與美結合，就是工藝。」創作者將生活經驗內化為創作養分，日複一日琢磨練習，而觀者從作品中能窺見創作者的心神意念，與土地帶來的養分。\r\n\r\n此次，透過徵件比賽及田野調查，邀請八位比賽得獎者及新竹縣內創作者，將他們的作品，展現在眾人面前。\r\n',
   'ID': '5472d0b0-37d1-47b6-bb1f-600ddc5118a9',
   'link': 'https://www.songshanculturalpark.org/Exhibition.aspx?ID=5472d0b0-37d1-47b6-bb1f-600ddc5118a9'},
  {'Title': '百變義大利：你一定要認識的關鍵設計！',
   'PublishDate': '2019/10/08~2020/02/09',
   'Place': '松菸',
   'shortInfo': '義大利，是現代品味、精緻生活的根源，1909年義大利詩人馬里內蒂發表「未來主義宣言」，對現代藝術設計的影響力穿越了百年；從經典的源頭了解，才能領受美好事物根本的價值所在。',
   'ID': 'bf0d432f-030f-4d26-b451-5486bd05eea2',
   'link': 'https://www.songshanculturalpark.org/Exhibition.aspx?ID=bf0d432f-030f-4d26-b451-5486bd05eea2'},
  {'Title': '德明財經科技大學多媒體設計系第十三屆畢業成果發表展「計．生」',
   'PublishDate': '2019/11/02~2019/11/04',
   'Place': '松菸',
   'shortInfo': '設計，始終寄生於我們腦海深處，卻從未真正找到過它。\r\n這次我們將熟睡中的設計因子喚醒，揭開全新的領域，\r\n讓小小的設計因子，逐漸成長、茁壯，在舞台上綻放自我，\r\n每個人皆可與設計拼湊出無限可能，開創不同局面。\r\n所以設計，便由此而生。\r\n',
   'ID': 'e59d3fe3-a44a-4eb5-870c-ad2068eb6bf5',
   'link': 'https://www.songshanculturalpark.org/Exhibition.aspx?ID=e59d3fe3-a44a-4eb5-870c-ad2068eb6bf5'},
  {'Title': '2019大城小肆音樂劇節',
   'PublishDate': '2019/10/11~2019/11/24',
   'Place': '松菸',
   'shortInfo': '10/11─11/24第二屆《大城小肆音樂劇節》在松菸，開幕派對、藝文沙龍講座、音樂劇論壇、創意競賽、音樂劇演出輪番上陣，這個秋天，讓我們在愛裡相遇，讓我們用滿滿的音樂劇趕走這座城市的寂寞。',
   'ID': '2ba580b9-635e-4f57-b45c-309b5b485154',
   'link': 'https://www.songshanculturalpark.org/Exhibition.aspx?ID=2ba580b9-635e-4f57-b45c-309b5b485154'}],
 [{'Title': '11/29-12/15 松菸 Lab 新主藝熱烈售票中',
   'PublishDate': '2019/11/29~2019/12/15',
   'Place': '松菸',
   'shortInfo': '11/29-12/15 松菸 Lab 新主藝熱烈售票中\r\n「三檔自製實驗節目，14場突破框架的舞蹈演出」',
   'ID': 'b6333fa6-6448-4bfa-87af-82aeb3ab38d4',
   'link': 'https://www.songshanculturalpark.org/Exhibition.aspx?ID=b6333fa6-6448-4bfa-87af-82aeb3ab38d4'},
  {'Title': '嶼泥 Be with you - 水泥手作工作坊',
   'PublishDate': '2019/09/25~2019/11/25',
   'Place': '松菸',
   'shortInfo': '我們從一棟水泥建築，穿梭過另外一棟水泥建築，在台灣，水泥這一個材質，不僅不可或缺，更是充滿在每個日常印象裡。\r\n',
   'ID': '7fddf3ca-b76f-4783-b1ce-295dc86ccb6a',
   'link': 'https://www.songshanculturalpark.org/Exhibition.aspx?ID=7fddf3ca-b76f-4783-b1ce-295dc86ccb6a'},
  {'Title': '2019臺灣地方創生展',
   'PublishDate': '2019/11/01~2019/11/07',
   'Place': '松菸',
   'shortInfo': '因應臺灣人口結構以及國土發展的現況，行政院將2019訂為地方創生元年，以「地、產、人」為核心不斷地推動地方創生政策達到「均衡台灣」的目標願景。',
   'ID': '7bf902a6-b516-4c39-8554-9829ba5d5b5b',
   'link': 'https://www.songshanculturalpark.org/Exhibition.aspx?ID=7bf902a6-b516-4c39-8554-9829ba5d5b5b'},
  {'Title': '「一縷光芒的奇蹟」 英國窯鑄玻璃藝術 橫跨三代 天團來台特展',
   'PublishDate': '2019/09/08~2020/03/08',
   'Place': '松菸',
   'shortInfo': '世界70個國家博物館的收藏見證\r\n輝煌的英國國家玻璃藝術隊伍\r\n\r\n琉璃工房 2019最重量級的展覽！\r\n9位英國窯鑄玻璃藝術家創作跨海來台，由英國窯鑄玻璃開創先鋒──柯林．雷德 Colin Reid 領軍，從國寶級教父，到當代藝術菁英，橫跨三個精彩世代，將大英帝國最精湛的玻璃藝術，呈現給臺灣觀眾。',
   'ID': '4159b6ae-b84c-4f5f-a07b-8bb618c9ddf3',
   'link': 'https://www.songshanculturalpark.org/Exhibition.aspx?ID=4159b6ae-b84c-4f5f-a07b-8bb618c9ddf3'},
  {'Title': '松菸小賣所主題特展—Circle Of Life',
   'PublishDate': '2019/08/30~2019/11/21',
   'Place': '松菸',
   'shortInfo': '環保不是未來，而是現在，\r\n是一次一次的循環，是生生不息的轉動，\r\n在回收與再生的軌跡中，\r\n我們努力傾聽材料的聲音，實踐永續的意義，\r\n直到找回每一個屬於它們的地方……',
   'ID': '41b91291-b458-486f-87a4-345f363a4103',
   'link': 'https://www.songshanculturalpark.org/Exhibition.aspx?ID=41b91291-b458-486f-87a4-345f363a4103'},
  {'Title': '包浩斯 然後呢 Beyond Bauhaus',
   'PublishDate': '2019/08/23~2019/11/03',
   'Place': '松菸',
   'shortInfo': '「包浩斯 然後呢 Beyond Bauhaus」由經濟部工業局主辦，台灣創意設計中心執行，JC Architecture柏成設計策展，邀請台灣、中國、泰國、英國來自各領域的建築師、產品設計師、平面設計師與服裝設計師，從他們的作品抽絲剝繭，再思包浩斯精神，並試圖重現包浩斯的社會實驗，從「夜市」一個最日常的場域出發，拆解基本元素，引領觀眾走入包浩斯的思維空間，啟發觀者以新的角度重新觀察生活日常。',
   'ID': '3cdf335d-3e22-48a9-aab1-31ed97167346',
   'link': 'https://www.songshanculturalpark.org/Exhibition.aspx?ID=3cdf335d-3e22-48a9-aab1-31ed97167346'}]]

rawData
# Out:
# [[{'Title': '2019原創基地節',
#    'PublishDate': '2019/11/29~2019/12/08',
#    'Place': '松菸',
#    'shortInfo': '遊走於松菸的地景藝術—相會在原創基地節\r\n\r\n連續七年在十二月舉辦的松山文創園區「原創基地節」，是歲末最受歡迎的大型活動，邀集數十位藝術家和文創品牌攜手打造創意聚集，每每在寒風至，這年即將結束時，讓眾人深切期待到來；「原創基地節」充滿熱情充滿創意，在冷冷冬日裡，讓松山文創園區暖暖綻放光彩。\r\n\r\n一期一會，如此簡單的相會，我們與藝術與文創與古蹟，這般親近。\r\n\r\n',
#    'ID': 'e4bf4a34-3a20-478d-b846-c328def63fef',
#    'link': 'https://www.songshanculturalpark.org/Exhibition.aspx?ID=e4bf4a34-3a20-478d-b846-c328def63fef'},
#   {'Title': '臺東地方文化館生活日特展《臺東日常的動靜之間》',
#    'PublishDate': '2019/11/09~2019/11/10',
#    'Place': '松菸',
#    'shortInfo': '臺東地方文化館生活日特展-臺東日常的動靜之間是由臺東縣政府文化處主辦，帶領9間地方文化館舍，首次於縣外聯合策展，臺東的多元族群形塑出繽紛多元文化場域，將臺東日常縮影濃縮於這次的展覽中，期盼民眾走進特展，探看臺東日常的動靜之美，細品臺東在地文化的縮影，感受臺東生活的況味，你會愛上這個動靜皆迷人的地方，臺東。',
#    'ID': '26fcfaca-b936-4dd0-894c-5fcff5e27900',
#    'link': 'https://www.songshanculturalpark.org/Exhibition.aspx?ID=26fcfaca-b936-4dd0-894c-5fcff5e27900'},
#   {'Title': '台灣文創珠寶展',
#    'PublishDate': '2019/11/09~2019/11/10',
# ...

# %%
data = []

for ele in SSrawData:
    for subEle in ele:
        data.append(subEle)
        
data
# Out:
# [{'Title': '2019原創基地節',
#   'PublishDate': '2019/11/29~2019/12/08',
#   'Place': '松菸',
#   'shortInfo': '遊走於松菸的地景藝術—相會在原創基地節\r\n\r\n連續七年在十二月舉辦的松山文創園區「原創基地節」，是歲末最受歡迎的大型活動，邀集數十位藝術家和文創品牌攜手打造創意聚集，每每在寒風至，這年即將結束時，讓眾人深切期待到來；「原創基地節」充滿熱情充滿創意，在冷冷冬日裡，讓松山文創園區暖暖綻放光彩。\r\n\r\n一期一會，如此簡單的相會，我們與藝術與文創與古蹟，這般親近。\r\n\r\n',
#   'ID': 'e4bf4a34-3a20-478d-b846-c328def63fef',
#   'link': 'https://www.songshanculturalpark.org/Exhibition.aspx?ID=e4bf4a34-3a20-478d-b846-c328def63fef'},
#  {'Title': '臺東地方文化館生活日特展《臺東日常的動靜之間》',
#   'PublishDate': '2019/11/09~2019/11/10',
#   'Place': '松菸',
#   'shortInfo': '臺東地方文化館生活日特展-臺東日常的動靜之間是由臺東縣政府文化處主辦，帶領9間地方文化館舍，首次於縣外聯合策展，臺東的多元族群形塑出繽紛多元文化場域，將臺東日常縮影濃縮於這次的展覽中，期盼民眾走進特展，探看臺東日常的動靜之美，細品臺東在地文化的縮影，感受臺東生活的況味，你會愛上這個動靜皆迷人的地方，臺東。',
#   'ID': '26fcfaca-b936-4dd0-894c-5fcff5e27900',
#   'link': 'https://www.songshanculturalpark.org/Exhibition.aspx?ID=26fcfaca-b936-4dd0-894c-5fcff5e27900'},
#  {'Title': '台灣文創珠寶展',
#   'PublishDate': '2019/11/09~2019/11/10',
#   'Place': '松菸',
# ...

# %%
import pymysql

# 連線語法

host = "localhost"
port = 8889
user = "root"
password = "root"
database = "midReport"

conn = pymysql.connect(host=host,port=port,  password=password, db=database , user=user)

cursor = conn.cursor()

# data = cursor.execute("SELECT VERSION();")
cursor.execute("SELECT VERSION();")

data = cursor.fetchone()

print(data)
# Out:
# ('5.7.26',)

# %%
HSRawData= [{'name': 'ETtoday好朋友放閃音樂節', 'date': '2019/11/09', 'catagory': '展演活動品牌活動', 'id': '19100309163248463', 'link': 'https://www.huashan1914.com/w/huashan1914/exhibition_